# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vyankateshparkale36-cyber/vyankatesh-flyrank-ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# My lane is a ranking problem. The goal is to rank content pages by their expected search performance so that the content team can decide which pages to review first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Task type: Ranking")
# Out:
# Task type: Ranking

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# My target is whether a content page shows a declining trend in the current window. I use trend_direction == "down" as a proxy label. This is a defined rule based on the observed trend field, not a direct prediction of Google's ranking algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Target: trend_direction == 'down'")
print("Target type: Proxy label")
# Out:
# Target: trend_direction == 'down'
# Target type: Proxy label

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# I will use Precision@50 as the success metric. It measures how many of the top 50 ranked pages match the target label. A higher Precision@50 means the review queue contains more relevant pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Success metric: Precision@50")
print("Higher is better.")
# Out:
# Success metric: Precision@50
# Higher is better.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# The unit of analysis is one content page. Each row represents one anonymized content page with features describing its search performance and content characteristics.

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content/vyankatesh-flyrank-ml
# ['01_first_look_and_discovery.ipynb', 'GUIDE.md', 'DATA_USE.md', 'data', 'outputs', 'LICENSE', 'submission', 'AGENTS.md', 'docs', 'SETUP.md', '.github', 'README.md', '.git', 'work', 'skills', '.gitignore', 'notebooks', 'CLAUDE.md', 'requirements.txt', 'scripts']

# %%
import os

for root, dirs, files in os.walk("/content"):
    if "content_refresh_anonymized.csv" in files:
        print(os.path.join(root, "content_refresh_anonymized.csv"))
# Out:
# /content/vyankatesh-flyrank-ml/data/raw/content_refresh_anonymized.csv

# %%
# !git clone https://github.com/vyankateshparkale36-cyber/vyankatesh-flyrank-ml.git
# Out:
# Cloning into 'vyankatesh-flyrank-ml'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 135 (delta 44), reused 94 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (135/135), 1.87 MiB | 15.71 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %%
# %cd /content/vyankatesh-flyrank-ml
# Out:
# /content/vyankatesh-flyrank-ml

# %%
# !ls data/raw
# Out:
# content_refresh_anonymized.csv

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

display(df.head())
# Out:
# Rows: 30000
# Columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule would be too simple because content performance depends on multiple signals such as search demand, impressions, clicks, position, content characteristics, and recent trends. These signals can interact in different ways across pages. A machine learning model can learn patterns from multiple features and produce a ranked review queue instead of relying on one fixed threshold.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Reason: Multiple signals interact across content pages.")
print("ML can combine these signals to produce a ranked review queue.")
# Out:
# Reason: Multiple signals interact across content pages.
# ML can combine these signals to produce a ranked review queue.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
